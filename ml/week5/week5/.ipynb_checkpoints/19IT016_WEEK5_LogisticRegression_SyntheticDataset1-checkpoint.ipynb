# %% [markdown]
# ID no: 19IT016
# Name: Manav Butani

# %% [markdown]
# # Flow of implementation
# - Import required libraries
# - Load dataset and Divide in Features and Target
# - Clean Dataset (Exchange missing values with apropreate value)
# - Divide dataset in train-test split
# - Fit the model on training data
# - Check for Goodness of Fit using MSE/RMSE/R2_Score

# %% [markdown]
# # what is Logistic Regression ?
# **Logistic Regression is a Machine Learning algorithm which is used for the classification problems, it is a predictive analysis algorithm and based on the concept of probability.**
#
# # What are the types of logistic regression
# **Binary Classification (eg. 0 and 1) only two outcomes,**,
# **MultiClass Classification (eg. Cats, dogs or Sheep's) more than two counts**

# %% [markdown]
# # Dataset Declaration
#
# Here,Girnar Hills' Tourists trying to claim Girnar Summit on day count 1. All are successful or not (0 or 1) related Binary Classification Synthetic Dataset is created.
#
# Features are Age,
# Time(0 to 23.59) means that 24Hr format,
# Weather(hot, cool, rainy),
# Rope-Way(0 or 1) means that taking Rope-Way to climb Girnar,
# Exersize(0 or 1) means that tourist is regular in Exersize or not,
# Traffic Rate(0 t0 1) means traffic on that day.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Girnar_Tourism.xlsx")
df
# Out:
#      Age   Time Weather  Group  Rop-Way  Exersize  Weight  Trafic Rate  \
# 0   20.0   7.00     Hot    4.0      0.0       1.0     3.0         0.70
# 1   21.0   5.00    Cool    5.0      0.0       1.0     7.0         0.80
# 2   20.0   4.75   Rainy    3.0      0.0       1.0     2.8         0.40
# 3   66.0   5.50    Cool    3.0      0.0       1.0     1.5         0.70
# 4   24.0   4.75    Cool   10.0      1.0       0.0     2.7         0.70
# 5   24.0   4.75    Cool    5.0      1.0       0.0     2.7         0.78
# 6   10.0   5.00     Hot    4.0      1.0       0.0     1.2         0.60
# 7   15.0   5.00   Rainy    3.0      0.0       0.0     2.5         0.50
# 8   12.0   5.00     Hot    6.0      1.0       1.0     4.5         1.00
# 9   17.0   5.00     Hot    5.0      0.0       1.0     4.5         0.60
# 10  65.0   8.00    Cool    4.0      1.0       1.0     2.0         0.60
# 11  37.0  10.00    Cool    1.0      0.0       1.0     3.0         0.65
# 12  66.0   5.50    Cool    3.0      0.0       1.0     1.5         1.00
# 13  21.0   5.00    Cool    5.0      0.0       1.0     5.0         0.80
# 14  23.0   8.00     Hot    5.0      0.0       1.0     4.0         0.70
# 15  33.0   6.50    Cool    6.0      1.0       1.0     6.0         1.00
# 16  28.0   5.00    Cool    4.0      1.0       1.0     0.0         0.90
# 17  21.0   4.00   Rainy    2.0      1.0       1.0     4.0         1.00
# 18  42.0   5.00     Hot    4.0      0.0       1.0     2.3         0.60
# 19  35.0   5.00     Hot    4.0      0.0       0.0     1.2         0.60
# 20   NaN    NaN   Rainy    NaN      NaN       NaN     NaN          NaN
# 21  37.0  10.00     Hot    1.0      0.0       1.0     3.0         0.65
# 22  21.0   4.00   Rainy    6.0      1.0       1.0     1.0         0.30
# 23  35.0   7.00   Rainy    4.0      1.0       1.0     0.0         0.20
# 24  50.0   8.00    Cool    4.0      1.0       1.0     2.0         1.00
# 25  23.0   8.00     Hot    5.0      1.0       1.0     4.0         0.70
# 26  20.0   7.00     Hot    4.0      0.0       1.0     3.0         0.70
# 27  21.0   5.00    Cool    5.0      0.0       1.0     7.0         0.80
# 28  20.0   4.75   Rainy    3.0      0.0       1.0     2.8         0.40
# 29  66.0   5.50    Cool    3.0      0.0       1.0     1.5         0.70
# 30  24.0   4.75    Cool   10.0      1.0       0.0     2.7         0.70
# 31  24.0   4.75    Cool    5.0      1.0       0.0     2.7         0.78
# 32  10.0   5.00     Hot    4.0      1.0       0.0     1.2         0.60
# 33  15.0   5.00   Rainy    3.0      0.0       0.0     2.5         0.50
# 34  12.0   5.00     Hot    6.0      1.0       1.0     4.5         1.00
# 35  17.0   5.00     Hot    5.0      0.0       1.0     4.5         0.60
# 36  65.0   8.00    Cool    4.0      1.0       1.0     2.0         0.60
# 37  37.0  10.00    Cool    1.0      0.0       1.0     3.0         0.65
# 38  66.0   5.50    Cool    3.0      0.0       1.0     1.5         1.00
#
#     Success
# 0         1
# 1         0
# 2         0
# 3         1
# 4         0
# 5         1
# 6         1
# 7         0
# 8         1
# 9         1
# 10        1
# 11        1
# 12        0
# 13        1
# 14        0
# 15        1
# 16        1
# 17        0
# 18        1
# 19        0
# 20        0
# 21        0
# 22        0
# 23        0
# 24        0
# 25        1
# 26        1
# 27        0
# 28        0
# 29        1
# 30        0
# 31        1
# 32        1
# 33        0
# 34        1
# 35        1
# 36        1
# 37        1
# 38        0

# %%
print(df.shape)
print(len(df))
# Out:
# (39, 9)
# 39

# %% [markdown]
# Below we can see lot of duplicate rows present in data, so removing them

# %%
df.duplicated() #shows duplicate rows in dataframe
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.info() #here, Weather datatype is object and that contains three value Hot, Cool, Rainy
# consider Cool=1, Hot=.5 and Rainy=0
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 0 to 25
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          25 non-null     float64
#  1   Time         25 non-null     float64
#  2   Weather      26 non-null     object
#  3   Group        25 non-null     float64
#  4   Rop-Way      25 non-null     float64
#  5   Exersize     25 non-null     float64
#  6   Weight       25 non-null     float64
#  7   Trafic Rate  25 non-null     float64
#  8   Success      26 non-null     int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 2.0+ KB

# %%
df["Weather"].replace(to_replace="Hot",value=0.5, inplace=True)
df["Weather"].replace(to_replace="Rainy",value=0, inplace=True)
df["Weather"].replace(to_replace="Cool",value=1, inplace=True)

# %% [markdown]
# Below we can see that there is null values present in Age, Time, Group, Rop-Way ,Exersize, Weight, and Trafic Rate.
#
#
# so put averange value of Age,Trafic Rate, Weight data where null values is present
#
# and for Group replace it with mode value
#
# and for Time replace it with meadian value
#
# and for Rop-Way and Exersize take random value

# %%
df.isnull().sum()
# Out:
# Age            1
# Time           1
# Weather        0
# Group          1
# Rop-Way        1
# Exersize       1
# Weight         1
# Trafic Rate    1
# Success        0
# dtype: int64

# %%
avg_age = df['Age'].mean()
df['Age'].fillna(avg_age,inplace=True)

avg_traf = df['Trafic Rate'].mean()
df['Trafic Rate'].fillna(avg_traf,inplace=True)

avg_Weight = df['Weight'].mean()
df['Weight'].fillna(avg_Weight,inplace=True)

#inplace true means that we are changing in the original data set

# %%
import math

grp = df['Group'].mode().max()
#print(grp) # 0 and 4 
#In mode possible that we are getting multiple answer 
# here also we get 0 and 4, thats why taking max number among them
df['Group'].fillna(grp,inplace=True)

tm = df['Time'].median()
df['Time'].fillna(tm,inplace=True)

# %%
import random

list1 = [0, 1]
df["Rop-Way"].fillna(random.choice(list1),inplace=True)
df["Exersize"].fillna(random.choice(list1),inplace=True)

# %%
df.isnull().sum()
# Out:
# Age            0
# Time           0
# Weather        0
# Group          0
# Rop-Way        0
# Exersize       0
# Weight         0
# Trafic Rate    0
# Success        0
# dtype: int64

# %%
df.describe()
# Out:
#              Age       Time    Weather      Group    Rop-Way   Exersize  \
# count  26.000000  26.000000  26.000000  26.000000  26.000000  26.000000
# mean   30.640000   5.990385   0.596154   4.230769   0.461538   0.769231
# std    15.904414   1.713886   0.400480   1.773306   0.508391   0.429669
# min    10.000000   4.000000   0.000000   1.000000   0.000000   0.000000
# 25%    21.000000   5.000000   0.500000   3.250000   0.000000   1.000000
# 50%    24.000000   5.000000   0.500000   4.000000   0.000000   1.000000
# 75%    36.500000   7.000000   1.000000   5.000000   1.000000   1.000000
# max    66.000000  10.000000   1.000000  10.000000   1.000000   1.000000
#
#           Weight  Trafic Rate    Success
# count  26.000000    26.000000  26.000000
# mean    2.856000     0.699200   0.500000
# std     1.696132     0.210844   0.509902
# min     0.000000     0.200000   0.000000
# 25%     1.625000     0.600000   0.000000
# 50%     2.750000     0.700000   0.500000
# 75%     4.000000     0.800000   1.000000
# max     7.000000     1.000000   1.000000

# %%
df.corr()
# Out:
#                   Age      Time   Weather     Group   Rop-Way  Exersize  \
# Age          1.000000  0.338274  0.436964 -0.297610 -0.107252  0.264574
# Time         0.338274  1.000000  0.241793 -0.387495 -0.086517  0.349934
# Weather      0.436964  0.241793  1.000000  0.192802  0.068006  0.134110
# Group       -0.297610 -0.387495  0.192802  1.000000  0.409559 -0.242298
# Rop-Way     -0.107252 -0.086517  0.068006  0.409559  1.000000 -0.042258
# Exersize     0.264574  0.349934  0.134110 -0.242298 -0.042258  1.000000
# Weight      -0.347711  0.026254  0.175601  0.199005 -0.193529  0.218449
# Trafic Rate  0.136374 -0.013770  0.553014  0.051865  0.145385  0.139525
# Success     -0.001578  0.085821  0.440732  0.044237  0.154303  0.182574
#
#                Weight  Trafic Rate   Success
# Age         -0.347711     0.136374 -0.001578
# Time         0.026254    -0.013770  0.085821
# Weather      0.175601     0.553014  0.440732
# Group        0.199005     0.051865  0.044237
# Rop-Way     -0.193529     0.145385  0.154303
# Exersize     0.218449     0.139525  0.182574
# Weight       1.000000     0.415315  0.118956
# Trafic Rate  0.415315     1.000000  0.201060
# Success      0.118956     0.201060  1.000000

# %% [markdown]
# **Why you want to apply regression on selected dataset?**
#
# Because our Y which is target variable is of continuous type so we can apply regression
#
# **How many total observations in data?**
#
# There are total 26 observations after filtering. Before filtering there was a 39 observations.
#
# **How many independent variables?**
#
# In This dataset,we could say Age, Time,	Weather, Group,	Rop-Way, Exersize,	Weight, Trafic Rate are the independent variables.
#
# **Which is dependent variable?**
#
# Success is the dependent variable.
#
# **Which are most useful variable in estimation? Prove using correlation.**
#
# In this dataset Weather, Rop-Way, Exersize,	Weight, Trafic Rate are useful.

# %%
plt.scatter(df["Trafic Rate"],df["Success"])

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.loc[:,["Weather", "Rop-Way", "Exersize","Weight", "Trafic Rate"]]
Y = df.iloc[:,-1] # last column of the df
#X
#print("----")
#Y
# df.loc[rows,["column name 1", "colunm name 50", "required column name"]]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=2)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# (rows, columns)
# Out:
# (18, 5)
# (8, 5)
# (18,)
# (8,)

# %%
X_test
# Out:
#     Weather  Rop-Way  Exersize  Weight  Trafic Rate
# 24      1.0      1.0       1.0   2.000       1.0000
# 0       0.5      0.0       1.0   3.000       0.7000
# 9       0.5      0.0       1.0   4.500       0.6000
# 20      0.0      0.0       0.0   2.856       0.6992
# 16      1.0      1.0       1.0   0.000       0.9000
# 12      1.0      0.0       1.0   1.500       1.0000
# 6       0.5      1.0       0.0   1.200       0.6000
# 3       1.0      0.0       1.0   1.500       0.7000

# %%
Y_test
# Out:
# 24    0
# 0     1
# 9     1
# 20    0
# 16    1
# 12    0
# 6     1
# 3     1
# Name: Success, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
reg = LogisticRegression()
reg.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
reg.predict(X_test)
# Out:
# array([1, 0, 0, 0, 1, 0, 0, 0], dtype=int64)

# %%
reg.score(X_test,Y_test)
# Out:
# 0.375

# %% [markdown]
# ###  **Check for Goodness of Fit using MSE/RMSE/R2_Score**

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# model evaluation for training set

Y_train_predict = reg.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, Y_train_predict)))
r2 = r2_score(Y_train, Y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print(f'RMSE is {rmse}')
print(f'R2 score is {r2}')
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 0.408248290463863
# R2 score is 0.32500000000000007

# %%
# model evaluation for testing set

Y_test_predict = reg.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, Y_test_predict)))
r2 = r2_score(Y_test, Y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print(f'RMSE is {rmse}')
print(f'R2 score is {r2}')
print("\n")
# Out:
# The model performance for testing set
# --------------------------------------
# RMSE is 0.7905694150420949
# R2 score is -1.6666666666666665
